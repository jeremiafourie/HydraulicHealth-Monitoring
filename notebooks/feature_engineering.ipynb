# %%
# 03_feature_engineering.ipynb
import pandas as pd, numpy as np, os
df = pd.read_csv("../data/processed/hydraulic_cycles.csv")

def summarize(df, prefix, n):
    cols = [f"{prefix}_{i}" for i in range(n)]
    arr = df[cols].values
    return pd.DataFrame({
        f"{prefix}_mean":  arr.mean(axis=1),
        f"{prefix}_std":   arr.std(axis=1),
        f"{prefix}_slope": np.polyfit(np.arange(n), arr.T, 1)[0]
    })

sensor_defs = [
    ("PS1",6000),("PS2",6000),("PS3",6000),("PS4",6000),("PS5",6000),("PS6",6000),
    ("EPS1",6000),
    ("FS1",600),("FS2",600),
    ("TS1",60),("TS2",60),("TS3",60),("TS4",60),
    ("VS1",60),("CE",60),("CP",60),("SE",60)
]
feat_list = [summarize(df, p, n) for p,n in sensor_defs]
X = pd.concat(feat_list, axis=1)
y = df[["cooler_pct","valve_pct","pump_leak","acc_pressure"]]

out = pd.concat([X, y], axis=1)
os.makedirs("../data/processed", exist_ok=True)
out.to_csv("../data/processed/features.csv", index=False)
print("Features:", out.shape)
out.head()
# Out:
# Features: (2205, 55)
#      PS1_mean    PS1_std  PS1_slope    PS2_mean    PS2_std  PS2_slope  \
# 0  160.673492  13.938147  -0.004043  109.466914  47.110581   0.017231
# 1  160.603320  14.117791  -0.004177  109.354890  47.041690   0.017187
# 2  160.347720  14.191436  -0.004211  109.158845  46.988144   0.017162
# 3  160.188088  14.226617  -0.004222  109.064807  46.968307   0.017157
# 4  160.000472  14.275244  -0.004249  108.931434  46.871040   0.017109
#
#    PS3_mean   PS3_std  PS3_slope  PS4_mean  ...   CP_mean    CP_std  CP_slope  \
# 0  1.991475  0.945626   0.000281       0.0  ...  1.862750  0.277047 -0.015649
# 1  1.976234  0.941889   0.000278       0.0  ...  1.255550  0.073981 -0.004121
# 2  1.972224  0.943422   0.000279       0.0  ...  1.113217  0.023069 -0.000819
# 3  1.946575  0.935456   0.000268       0.0  ...  1.062150  0.024415  0.000114
# 4  1.922707  0.930258   0.000268       0.0  ...  1.070467  0.021297  0.000646
#
# ...
